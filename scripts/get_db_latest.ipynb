# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\rjayaprakash\appdata\roaming\python\python311\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\rjayaprakash\appdata\roaming\python\python311\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rjayaprakash\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rjayaprakash\appdata\roaming\python\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rjayaprakash\appdata\roaming\python\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rjayaprakash\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
def read_sqlite(dbfile):
    import sqlite3
    from pandas import read_sql_query, read_sql_table

    with sqlite3.connect(dbfile) as dbcon:
        tables = list(read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", dbcon)['name'])
        out = {tbl : read_sql_query(f"SELECT * from {tbl}", dbcon) for tbl in tables}

    return out

# %%
db = read_sqlite("../input_files/steel_moment_axial_combos_latest.db")

# %%
db.keys()
# Out:
# dict_keys(['Wshapes_Table6_1', 'wShapes'])

# %%
w_shapes = db['wShapes']
w_shapes.shape
# Out:
# (2589600, 9)

# %%
Wshapes_Table6_1 = db['Wshapes_Table6_1']
Wshapes_Table6_1.shape
# Out:
# (6139000, 9)

# %%
w_shapes.head()
# Out:
#    profile  length_ft  weight_plf   Cb  Pr_over_Pc  Pr_k         Pc_k  \
# 0  W44X290          0   290.63328  1.0         0.0   0.0  2397.118549
# 1  W44X290          0   290.63328  1.1         0.0   0.0  2397.118549
# 2  W44X290          0   290.63328  1.2         0.0   0.0  2397.118549
# 3  W44X290          0   290.63328  1.3         0.0   0.0  2397.118549
# 4  W44X290          0   290.63328  1.4         0.0   0.0  2397.118549
#
#       Mmax_ftk       Mc_ftk
# 0  3517.964072  3517.964072
# 1  3517.964072  3517.964072
# 2  3517.964072  3517.964072
# 3  3517.964072  3517.964072
# 4  3517.964072  3517.964072

# %%
Wshapes_Table6_1.head()
# Out:
#    profile  length_ft  weight_plf   Cb  Pr_over_Pc  Pr_k     Pc_k  Mmax_ftk  \
# 0  W44X335          0         335  1.0         0.0   0.0  2890.17    4040.4
# 1  W44X335          0         335  1.1         0.0   0.0  2890.17    4040.4
# 2  W44X335          0         335  1.2         0.0   0.0  2890.17    4040.4
# 3  W44X335          0         335  1.3         0.0   0.0  2890.17    4040.4
# 4  W44X335          0         335  1.4         0.0   0.0  2890.17    4040.4
#
#    Mc_ftk
# 0  4040.4
# 1  4040.4
# 2  4040.4
# 3  4040.4
# 4  4040.4

# %%
primary_keys = ['profile', 'length_ft', 'Cb', 'Pr_over_Pc']

merged_df = w_shapes.merge(Wshapes_Table6_1, on=primary_keys, suffixes=('_w_shapes', '_Wshapes_Table6_1'))

# %%
merged_df.shape
# Out:
# (514680, 14)

# %%
merged_df.head()
# Out:
#    profile  length_ft  weight_plf_w_shapes   Cb  Pr_over_Pc  Pr_k_w_shapes  \
# 0  W44X290          0            290.63328  1.0         0.0            0.0
# 1  W44X290          0            290.63328  1.1         0.0            0.0
# 2  W44X290          0            290.63328  1.2         0.0            0.0
# 3  W44X290          0            290.63328  1.3         0.0            0.0
# 4  W44X290          0            290.63328  1.4         0.0            0.0
#
#    Pc_k_w_shapes  Mmax_ftk_w_shapes  Mc_ftk_w_shapes  \
# 0    2397.118549        3517.964072      3517.964072
# 1    2397.118549        3517.964072      3517.964072
# 2    2397.118549        3517.964072      3517.964072
# 3    2397.118549        3517.964072      3517.964072
# 4    2397.118549        3517.964072      3517.964072
#
#    weight_plf_Wshapes_Table6_1  Pr_k_Wshapes_Table6_1  Pc_k_Wshapes_Table6_1  \
# 0                          290                    0.0                2398.08
# 1                          290                    0.0                2398.08
# 2                          290                    0.0                2398.08
# 3                          290                    0.0                2398.08
# 4                          290                    0.0                2398.08
#
#    Mmax_ftk_Wshapes_Table6_1  Mc_ftk_Wshapes_Table6_1
# 0                    3513.39                  3513.39
# 1                    3513.39                  3513.39
# 2                    3513.39                  3513.39
# 3                    3513.39                  3513.39
# 4                    3513.39                  3513.39

# %%
threshold = 2

# %%
def calculate_percent_difference(x1, x2):
    if x1 + x2 == 0:
        return 0
    return (abs(x1 - x2) / ((x1 + x2) / 2)) * 100

# %%
to_compare_columns = ['Pr_k', 'Pc_k', 'Mmax_ftk', 'Mc_ftk']

passes2 = 0
failures2 = 0
failed_items2 = []

for index, row in merged_df.iterrows():

    differences = [calculate_percent_difference(row[f'{col}_w_shapes'], row[f'{col}_Wshapes_Table6_1']) for col in to_compare_columns]

    if all(diff <= threshold for diff in differences):
        passes2 += 1
    else:
        failures2 += 1
        failed_items2.append(index)

print('Threshold: ', threshold)
print('Number of passes 2:', passes2)
print('Number of failures 2:', failures2)
print("Failed Items 2:")
merged_df.loc[failed_items2]
# Out:
# Threshold:  2
# Number of passes 2: 512622
# Number of failures 2: 2058
# Failed Items 2:
#        profile  length_ft  weight_plf_w_shapes   Cb  Pr_over_Pc  \
# 404400  W14X90          0              90.1848  1.0         0.0
# 404401  W14X90          0              90.1848  1.1         0.0
# 404402  W14X90          0              90.1848  1.2         0.0
# 404403  W14X90          0              90.1848  1.3         0.0
# 404404  W14X90          0              90.1848  1.4         0.0
# ...        ...        ...                  ...  ...         ...
# 406915  W14X90         50              90.1848  2.5         0.6
# 406916  W14X90         50              90.1848  2.6         0.6
# 406917  W14X90         50              90.1848  2.7         0.6
# 406918  W14X90         50              90.1848  2.8         0.6
# 406919  W14X90         50              90.1848  2.9         0.6
#
#         Pr_k_w_shapes  Pc_k_w_shapes  Mmax_ftk_w_shapes  Mc_ftk_w_shapes  \
# 404400        0.00000     793.413112         391.716567       391.716567
# 404401        0.00000     793.413112         391.716567       391.716567
# 404402        0.00000     793.413112         391.716567       391.716567
# 404403        0.00000     793.413112         391.716567       391.716567
# 404404        0.00000     793.413112         391.716567       391.716567
# ...               ...            ...                ...              ...
# 406915       90.68557     151.142616         176.272455       391.716567
# 406916       90.68557     151.142616         176.272455       391.716567
# 406917       90.68557     151.142616         176.272455       391.716567
# 406918       90.68557     151.142616         176.272455       391.716567
# 406919       90.68557     151.142616         176.272455       391.716567
#
#         weight_plf_Wshapes_Table6_1  Pr_k_Wshapes_Table6_1  \
# 404400                           90                   0.00
# 404401                           90                   0.00
# 404402                           90                   0.00
# 404403                           90                   0.00
# 404404                           90                   0.00
# ...                             ...                    ...
# 406915                           90                  90.91
# 406916                           90                  90.91
# 406917                           90                  90.91
# 406918                           90                  90.91
# 406919                           90                  90.91
#
#         Pc_k_Wshapes_Table6_1  Mmax_ftk_Wshapes_Table6_1  \
# 404400                 793.65                     381.50
# 404401                 793.65                     381.50
# 404402                 793.65                     381.50
# 404403                 793.65                     381.50
# 404404                 793.65                     381.50
# ...                       ...                        ...
# 406915                 151.52                     171.67
# 406916                 151.52                     171.67
# 406917                 151.52                     171.67
# 406918                 151.52                     171.67
# 406919                 151.52                     171.67
#
#         Mc_ftk_Wshapes_Table6_1
# 404400                    381.5
# 404401                    381.5
# 404402                    381.5
# 404403                    381.5
# 404404                    381.5
# ...                         ...
# 406915                    381.5
# 406916                    381.5
# 406917                    381.5
# 406918                    381.5
# 406919                    381.5
#
# [2058 rows x 14 columns]

# %%
threshold = 1

# %%
numeric_columns = ['Pr_k', 'Pc_k', 'Mmax_ftk', 'Mc_ftk']
pass_counts = {col: 0 for col in numeric_columns}
fail_counts = {col: 0 for col in numeric_columns}

# Create a list to store the details of failed items
failed_items_details_df = []

# Iterate through each row
for index, row in merged_df.iterrows():
    # Check the difference for each numeric column
    differences = [calculate_percent_difference(row[f'{col}_w_shapes'], row[f'{col}_Wshapes_Table6_1']) for col in numeric_columns]

    # Check if differences for each column are within 5%
    for col, diff in zip(numeric_columns, differences):
        if diff <= threshold:
            pass_counts[col] += 1
        else:
            fail_counts[col] += 1

# Print the number of passes and failures for each column
print('Pass/Fail counts for each column for threshold: ',threshold)
for col in numeric_columns:
    print(f'{col}: Passes={pass_counts[col]}, Failures={fail_counts[col]}')
# Out:
# Pass/Fail counts for each column for threshold:  1
# Pr_k: Passes=514000, Failures=680
# Pc_k: Passes=513840, Failures=840
# Mmax_ftk: Passes=510672, Failures=4008
# Mc_ftk: Passes=510672, Failures=4008

# %% [markdown]
# ## Run below code to print the failing test cases.
#
# Set range as desired for faster processing
#
#     set in : for index, row in merged_df[400000:500000].iterrows():

# %%
to_compare_columns = ['Pr_k', 'Pc_k', 'Mmax_ftk', 'Mc_ftk']
passes3 = 0
failures3 = 0
failed_items_details3 = []

for index, row in merged_df[400000:500000].iterrows():
    differences = [calculate_percent_difference(row[f'{col}_w_shapes'], row[f'{col}_Wshapes_Table6_1']) for col in to_compare_columns]

    # Check if all differences are within 5%
    if all(diff <= threshold for diff in differences):
        passes3 += 1
    else:
        failures3 += 1
        # uncomment below to see failing cases

        # print(index)
        # print(to_compare_columns)
        # print(differences)
        # print(row)

        failed_items_details3.append({
            'index': index,
            'differences': {col: diff for col, diff in zip(to_compare_columns, differences)}
        })

# Print the number of passes and failures
print('Threshold: ',threshold)
print('Number of passes 3 for the first 500 rows of merged_df:', passes3)
print('Number of failures 3 for the first 500 rows of merged_df:', failures3)

# Print details of failed items
print("\nFailed Items Details for the specific range of rows in merged_df:")
for failed_item in failed_items_details3:
    print(f"Failed item at index : {failed_item['index']}:")
    for col, diff in failed_item['differences'].items():
        if diff > threshold:
            print(f"  {col}: {diff:.2f}%")
# Out:
# Threshold:  1
# Number of passes 3 for the first 500 rows of merged_df: 95632
# Number of failures 3 for the first 500 rows of merged_df: 4368
#
# Failed Items Details for the first 500 rows of merged_df:
# Failed item at index : 404400:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404401:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404402:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404403:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404404:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404405:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404406:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404407:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404408:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404409:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404410:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404411:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404412:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404413:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404414:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404415:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404416:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404417:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404418:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404419:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404420:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404421:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404422:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404423:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404424:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404425:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404426:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404427:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404428:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404429:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404430:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404431:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404432:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 404433:
#   Mmax_ftk: 2.64%
#   Mc_ftk: 2.64%
# Failed item at index : 

#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465499:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465508:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465509:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465510:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465511:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465512:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465513:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465514:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465515:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465516:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465517:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465518:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465519:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465528:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465529:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465530:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465531:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465532:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465533:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465534:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465535:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465536:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465537:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465538:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465539:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465548:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465549:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465550:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465551:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465552:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465553:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465554:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465555:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465556:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465557:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465558:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465559:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465568:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465569:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465570:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465571:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465572:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465573:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465574:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465575:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465576:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465577:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465578:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465579:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465588:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465589:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465590:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465591:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465592:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465593:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465594:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465595:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465596:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465597:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465598:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465599:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465609:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465610:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465611:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465612:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465613:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465614:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465615:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465616:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465617:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465618:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465619:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465629:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465630:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465631:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465632:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465633:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465634:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465635:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465636:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465637:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465638:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465639:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465649:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465650:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465651:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465652:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465653:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465654:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465655:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465656:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465657:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465658:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465659:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465669:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465670:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465671:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465672:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465673:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465674:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465675:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465676:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465677:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465678:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465679:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465689:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465690:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465691:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465692:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465693:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465694:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465695:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465696:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465697:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465698:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465699:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465709:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465710:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465711:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465712:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465713:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465714:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465715:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465716:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465717:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465718:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 465719:
#   Mmax_ftk: 1.87%
#   Mc_ftk: 1.87%
# Failed item at index : 496800:
#   Pc_k: 1.07%
# Failed item at index : 496801:
#   Pc_k: 1.07%
# Failed item at index : 496802:
#   Pc_k: 1.07%
# Failed item at index : 496803:
#   Pc_k: 1.07%
# Failed item at index : 496804:
#   Pc_k: 1.07%
# Failed item at index : 496805:
#   Pc_k: 1.07%
# Failed item at index : 496806:
#   Pc_k: 1.07%
# Failed item at index : 496807:
#   Pc_k: 1.07%
# Failed item at index : 496808:
#   Pc_k: 1.07%
# Failed item at index : 496809:
#   Pc_k: 1.07%
# Failed item at index : 496810:
#   Pc_k: 1.07%
# Failed item at index : 496811:
#   Pc_k: 1.07%
# Failed item at index : 496812:
#   Pc_k: 1.07%
# Failed item at index : 496813:
#   Pc_k: 1.07%
# Failed item at index : 496814:
#   Pc_k: 1.07%
# Failed item at index : 496815:
#   Pc_k: 1.07%
# Failed item at index : 496816:
#   Pc_k: 1.07%
# Failed item at index : 496817:
#   Pc_k: 1.07%
# Failed item at index : 496818:
#   Pc_k: 1.07%
# Failed item at index : 496819:
#   Pc_k: 1.07%
# Failed item at index : 496820:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496821:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496822:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496823:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496824:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496825:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496826:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496827:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496828:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496829:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496830:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496831:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496832:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496833:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496834:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496835:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496836:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496837:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496838:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496839:
#   Pr_k: 1.01%
#   Pc_k: 1.07%
# Failed item at index : 496840:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496841:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496842:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496843:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496844:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496845:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496846:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496847:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496848:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496849:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496850:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496851:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496852:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496853:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496854:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496855:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496856:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496857:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496858:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496859:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496860:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496861:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496862:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496863:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496864:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496865:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496866:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496867:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496868:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496869:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496870:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496871:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496872:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496873:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496874:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496875:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496876:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496877:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496878:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496879:
#   Pr_k: 1.05%
#   Pc_k: 1.07%
# Failed item at index : 496880:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496881:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496882:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496883:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496884:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496885:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496886:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496887:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496888:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496889:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496890:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496891:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496892:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496893:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496894:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496895:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496896:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496897:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496898:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496899:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496900:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496901:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496902:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496903:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496904:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496905:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496906:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496907:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496908:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496909:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496910:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496911:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496912:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496913:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496914:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496915:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496916:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496917:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496918:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
# Failed item at index : 496919:
#   Pr_k: 1.07%
#   Pc_k: 1.07%
